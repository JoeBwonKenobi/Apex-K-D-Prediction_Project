# %%
#Numpy
import numpy as np
from numpy import median

#Pandas
import pandas as pd

#Seaborn
import seaborn as sns

#matplotlib
import matplotlib.pyplot as plt

#Set global scikit-learn configuration
from sklearn import set_config


#Warnings
import warnings
warnings.filterwarnings("ignore")

# %%
A_df= pd.read_csv("/Users/davyd/OneDrive/Documents/ApexData_Allayna.csv")
A_df.info()
A_df.head(25)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Season              5 non-null      int64
#  1   Total Damage        5 non-null      int64
#  2   Total Kills         5 non-null      int64
#  3   Total Deaths        5 non-null      int64
#  4   K/D Ratio           5 non-null      float64
#  5   Total Wins          5 non-null      int64
#  6   Total Top 5 Finish  5 non-null      int64
#  7   Total Games Played  5 non-null      int64
#  8   Highest Kills       5 non-null      int64
#  9   Knockdowns          5 non-null      int64
#  10  Assists             5 non-null      int64
#  11  Teamates Revived    5 non-null      int64
#  12  Teamates Respawned  5 non-null      int64
#  13  Win Streak          5 non-null      int64
#  14  Win Rate %          5 non-null      object
#  15  Character           5 non-null      object
# ...

# %%
A_df['Cal K/D'] = A_df['Total Kills']/A_df['Total Deaths']

# %%
A_df['Top 5 %'] = A_df['Total Games Played']/A_df['Total Top 5 Finish']

# %%
A_df['kill/knock ratio'] = A_df['Total Kills']/A_df['Knockdowns']

# %%
#Saving the new dataframe to upload in the next notebook
A_df.to_csv('Allayna_data_frame', index=False)

# %%
# Calculate the average of the column
av5 = A_df["Total Kills"].mean()
print(av5)
# Out:
# 382.2

# %%
avd = A_df["Total Damage"].mean()
print(avd)
# Out:
# 148234.0

# %%
plt.bar(A_df['Season'], A_df['Total Games Played'])
# Set plot labels and title
plt.xlabel('Season')
plt.ylabel('Total games Played')
plt.xticks(rotation=35, fontsize = 12, fontweight = 'normal', ha = 'right');
plt.title('Total Games Played Per Season')

# Show the plot
plt.show()

# %%
plt.bar(A_df['Season'], A_df['Total Kills'])
# Set plot labels and title
plt.xlabel('Season')
plt.ylabel('Total Kills')
plt.xticks(rotation=35, fontsize = 12, fontweight = 'normal', ha = 'right');
plt.title('Total Kills by Season')

# Show the plot
plt.show()

# %%
plt.bar(A_df['Season'], A_df['K/D Ratio'])
# Set plot labels and title
plt.xlabel('Season')
plt.ylabel('K/D Ratio')
plt.xticks(rotation=35, fontsize = 12, fontweight = 'normal', ha = 'right');
plt.title('K/D by Season')

# Show the plot
plt.show()

# %%
plt.bar(A_df['Season'], A_df['kill/knock ratio'])
# Set plot labels and title
plt.xlabel('Season')
plt.ylabel('kill/knock ratio')
plt.xticks(rotation=35, fontsize = 12, fontweight = 'normal', ha = 'right');
plt.title('kill/knock ratio by Season')

# Show the plot
plt.show()

# %%
plt.bar(A_df['Season'], A_df['Assists'])
# Set plot labels and title
plt.xlabel('Season')
plt.ylabel('Total Assists')
plt.xticks(rotation=35, fontsize = 12, fontweight = 'normal', ha = 'right');
plt.title('Assists by Season')

# Show the plot
plt.show()

# %%
plt.bar(A_df['Season'], A_df['Top 5 %'])
# Set plot labels and title
plt.xlabel('Season')
plt.ylabel('Top 5 %')
plt.xticks(rotation=35, fontsize = 12, fontweight = 'normal', ha = 'right');
plt.title('Top 5 % by Season')

# Show the plot
plt.show()
